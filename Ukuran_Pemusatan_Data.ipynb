# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/hilalarsa/statistika-kel4/blob/master/Ukuran_Pemusatan_Data.ipynb)

# %% [markdown]
# ## Ukuran Pemusatan Data
#
# Dapat didefinisikan sebagai ukuran atau satuan yang digunakan untuk menghitung suatu gugus atau kumpulan dari banyak data. Salah satu kegunaannya adalah untuk menentukan bagaimana suatu kumpulan data dapat dibandingkan dengan kumpulan data lainnya tanpa perlu membandingkan masing-masing data, melainkan menggunaakn penghitungan data yang terpusat sehingga dapat mewakili keseluruhan nilai kumpulan data.
#
# Jenis pengukuran pemusatan data yang paling sering digunakan adalah :
# - Mean
# - Median
# - Modus
# - Kuartil
# - Desil
# - Persentil
#
#
# ## Mean
# ### **Rata-Rata untuk Data Tunggal**
#
# > $ \overline{X} = \frac{\sum x}{n} $ atau $ \overline{X} = \frac{x_{1}+x_{2}+ ...+x_{n}}{n} $
#
#
# Keterangan:
#
# *   $ ẋ $ = mean
# *   $ n $ = banyaknya data
#
# Contoh :
#
# Hitung rata-rata dari lebar kelopak bunga ( 4.6, 4.7, 4.7, 4.9, 5.0,5.1, 5.4, 5.6, 5.8, 6.3, 6.3, 6.5, 7.1, 7.3, 7.6)
#
# Penyelesaian:
#
# > $ \overline{X} = \frac{\sum x}{n} = \frac{4.6+4.7+4.7+4.9+5.0+5.1+5.4+5.6+5.8+6.3+6.5+7.1+7.3+7.6}{15} = \frac{80.6}{15} = 5.37 $
#
# <br><br>
#
# ### **Rata-Rata untuk Data Berkelompok**
#
# > $ \overline{X} =\frac{\sum fi . xi}{\sum fi} $
#
# Keterangan:
#
# * $ fi $ = frekuensi
# * $ xi $ = nilai tengah (jumlah tepi bawah dan tepi atas di bagi 2)
#
# |||||
# |--- |--- |--- |--- |
# |**Interval Jumlah**|**Frekuensi ( $f$ )**|**Nilai Tengah ( $x$ )**|**Frekuensi . Nilai Tengah ( $ f.x $ ) **|
# | 4.5 – 5 | 4 | 4.75 | 19 |
# | 5 – 5.5	| 3 | 5.2 | 15.6 |
# | 5.5 – 6	| 2 | 5.7 | 11.4 |
# | 6 - 6.5 | 2 | 6.3 | 12.6 |
# | 6.5 - 7 | 1 | 6.5 | 6.5 |
# | 7 - 7.5 | 2 | 7.2 | 14.4 |
# | 7.5 - 8 | 1 | 7.5 | 7.5 |
# | Jumlah | $\sum{f} = $ 	15 | | $ \sum{f.x = } 87 $ |
#
# Hasil : $ Mean =\frac{\sum fi.xi}{\sum fi} = \frac{87}{15} = 5,8 $

# %% [markdown]
# ## Median
#
# Median adalah nilai data yang terletak di tengah setelah data diurutkan.
#
# ---
#
# ### **Median untuk Data Tunggal**
#
# *   Jika banyaknya data n ganjil
#
#  $ Me = X_{\frac{n+1}{2}} $
#
# *   Jika banyaknya data n genap
#
#  $ Me = \frac{X_{\frac{n}{2}} + X_{\frac{n}{2}+1}}{2} $
#
# Keterangan :
#
# *   $ Me $ = Median
# *   $ n $ = jumlah data
# *   $ x $ = nilai data
#
# **Contoh :**
#
# 1.  Tentukan median dari data lebar kelopak bunga sbb : 4.6, 4.7, 4.7, 4.9, 5.0,5.1, 5.4, 5.6, 5.8, 6.3, 6.3, 6.5, 7.1, 7.3, 7.6
#
#  N= 12 (genap) => Jadi, mediannya adlah 5.6
#
# 2. Tentukan median dari data lebar kelopak bunga sbb : 4.6, 4.7, 4.7, 4.9, 5.0,5.1, 5.4, 5.6, 5.8, 6.3, 6.3, 6.5, 7.1, 7.3
#
#  $ Me = \frac{X_{\frac{n}{2}} + X_{\frac{n}{2}+1}}{2} $
#
#
#  $ Me = \frac{1}{2}(5.4 + 5.6) = \frac{1}{2}(11) = 11,5$
#
#
# ---
#
# ### **Median untuk data berkelompok**
#
# > $ Me = Tb + \frac{\frac{1}{2}n-F }{f}.c $
#
# Keterangan :
# *   $ Tb $ = Tepi bawah kelas median (Batas bawah – 0,5)
# *   $ F $ = Frekuensi kumulatif sebelum median
# *   $ f $ = Frekuensi
# *   $ c $ = Panjang kelas
# *   $ n $ = Jumlah frekuensi
#
# **Contoh :**
#
# |||||
# |--- |--- |--- |--- |
# |**Interval Jumlah**|**Frekuensi ( $f$ )**|**Frekuensi Kumulatif ( $x$ )**|
# | 4.5 – 5 | 4 | 4.75 |
# | 5 – 5.5	| 3 | 5.2 |
# | 5.5 – 6	| 2 | 5.7 |
# | 6 - 6.5 | 2 | 6.3 |
# | 6.5 - 7 | 1 | 6.5 |
# | 7 - 7.5 | 2 | 7.2 |
# | 7.5 - 8 | 1 | 7.5 |
# | Jumlah | $\sum{f} = $ 	15 | | - |
# ||||
#
# Penyelesaian :
#
# * Letak kelas median: Setengah dari seluruh data = 15 pada range 5.5-6.
# * $ Tb $ = 5.5 – 0,5 = 5
# * $ c $ = 0.5
# * $ n $ = 15
# * $ f $ = 2 (frekuensi kelas median)
# * $ F $ = 2 + 3 = 5
#
# $ Median = T_{b} + (\frac{\frac{1}{2}n-F}{f}).c = 5 + (\frac{\frac{1}{2}15-5}{2}).0.5 =6.25 $
