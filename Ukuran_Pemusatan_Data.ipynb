# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/hilalarsa/statistika-kel4/blob/master/Ukuran_Pemusatan_Data.ipynb)

# %% [markdown]
# ## Ukuran Pemusatan Data
#
# Dapat didefinisikan sebagai ukuran atau satuan yang digunakan untuk menghitung suatu gugus atau kumpulan dari banyak data. Salah satu kegunaannya adalah untuk menentukan bagaimana suatu kumpulan data dapat dibandingkan dengan kumpulan data lainnya tanpa perlu membandingkan masing-masing data, melainkan menggunaakn penghitungan data yang terpusat sehingga dapat mewakili keseluruhan nilai kumpulan data.
#
# Jenis pengukuran pemusatan data yang paling sering digunakan adalah :
# - Mean
# - Median
# - Modus
# - Kuartil
# - Desil
# - Persentil
#
#
# ## Mean
# ### **Rata-Rata untuk Data Tunggal**
#
# > $ \overline{X} = \frac{\sum x}{n} $ atau $ \overline{X} = \frac{x_{1}+x_{2}+ ...+x_{n}}{n} $
#
#
# Keterangan:
#
# *   $ x $ = mean
# *   $ n $ = banyaknya data
#
# Contoh :
#
# Hitung rata-rata dari lebar kelopak bunga ( 4.6, 4.7, 4.7, 4.9, 5.0,5.1, 5.4, 5.6, 5.8, 6.3, 6.3, 6.5, 7.1, 7.3, 7.6)
#
# Penyelesaian:
#
# > $ \overline{X} = \frac{\sum x}{n} = \frac{4.6+4.7+4.7+4.9+5.0+5.1+5.4+5.6+5.8+6.3+6.5+7.1+7.3+7.6}{15} = \frac{80.6}{15} = 5.37 $
#
# <br><br>
#
# ### **Rata-Rata untuk Data Berkelompok**
#
# > $ \overline{X} =\frac{\sum fi . xi}{\sum fi} $
#
# Keterangan:
#
# * $ fi $ = frekuensi
# * $ xi $ = nilai tengah (jumlah tepi bawah dan tepi atas di bagi 2)
#
# |||||
# |--- |--- |--- |--- |
# |**Interval Jumlah**|**Frekuensi ( $f$ )**|**Nilai Tengah ( $x$ )**|**Frekuensi . Nilai Tengah ( $ f.x $ ) **|
# | 4.5 – 5 | 4 | 4.75 | 19 |
# | 5 – 5.5	| 3 | 5.2 | 15.6 |
# | 5.5 – 6	| 2 | 5.7 | 11.4 |
# | 6 - 6.5 | 2 | 6.3 | 12.6 |
# | 6.5 - 7 | 1 | 6.5 | 6.5 |
# | 7 - 7.5 | 2 | 7.2 | 14.4 |
# | 7.5 - 8 | 1 | 7.5 | 7.5 |
# | Jumlah | $\sum{f} = $ 	15 | | $ \sum{f.x = } 87 $ |
#
# Hasil : $ Mean =\frac{\sum fi.xi}{\sum fi} = \frac{87}{15} = 5,8 $

# %% [markdown]
# ## Median
#
# Median adalah nilai data yang terletak di tengah setelah data diurutkan.
#
# ---
#
# ### **Median untuk Data Tunggal**
#
# *   Jika banyaknya data n ganjil
#
#  $ Me = X_{\frac{n+1}{2}} $
#
# *   Jika banyaknya data n genap
#
#  $ Me = \frac{X_{\frac{n}{2}} + X_{\frac{n}{2}+1}}{2} $
#
# Keterangan :
#
# *   $ Me $ = Median
# *   $ n $ = jumlah data
# *   $ x $ = nilai data
#
# **Contoh :**
#
# 1.  Tentukan median dari data lebar kelopak bunga sbb : 4.6, 4.7, 4.7, 4.9, 5.0,5.1, 5.4, 5.6, 5.8, 6.3, 6.3, 6.5, 7.1, 7.3, 7.6
#
#  N= 12 (genap) => Jadi, mediannya adlah 5.6
#
# 2. Tentukan median dari data lebar kelopak bunga sbb : 4.6, 4.7, 4.7, 4.9, 5.0,5.1, 5.4, 5.6, 5.8, 6.3, 6.3, 6.5, 7.1, 7.3
#
#  $ Me = \frac{X_{\frac{n}{2}} + X_{\frac{n}{2}+1}}{2} $
#
#
#  $ Me = \frac{1}{2}(5.4 + 5.6) = \frac{1}{2}(11) = 11,5$
#
#
# ---
#
# ### **Median untuk data berkelompok**
#
# > $ Me = Tb + \frac{\frac{1}{2}n-F }{f}.c $
#
# Keterangan :
# *   $ Tb $ = Tepi bawah kelas median (Batas bawah – 0,5)
# *   $ F $ = Frekuensi kumulatif sebelum median
# *   $ f $ = Frekuensi
# *   $ c $ = Panjang kelas
# *   $ n $ = Jumlah frekuensi
#
# **Contoh :**
#
# |||||
# |--- |--- |--- |--- |
# |**Interval Jumlah**|**Frekuensi ( $f$ )**|**Frekuensi Kumulatif ( $x$ )**|
# | 4.5 – 5 | 4 | 4.75 |
# | 5 – 5.5	| 3 | 5.2 |
# | 5.5 – 6	| 2 | 5.7 |
# | 6 - 6.5 | 2 | 6.3 |
# | 6.5 - 7 | 1 | 6.5 |
# | 7 - 7.5 | 2 | 7.2 |
# | 7.5 - 8 | 1 | 7.5 |
# | Jumlah | $\sum{f} = $ 	15 | | - |
# ||||
#
# Penyelesaian :
#
# * Letak kelas median: Setengah dari seluruh data = 15 pada range 5.5-6.
# * $ Tb $ = 5.5 – 0,5 = 5
# * $ c $ = 0.5
# * $ n $ = 15
# * $ f $ = 2 (frekuensi kelas median)
# * $ F $ = 2 + 3 = 5
#
# $ Median = T_{b} + (\frac{\frac{1}{2}n-F}{f}).c = 5 + (\frac{\frac{1}{2}15-5}{2}).0.5 =6.25 $

# %% [markdown]
# ## Modus
# Modus adalah data yang paling sering muncul atau memiliki frekuensi tertinggi.
#
#
# ---
#
# ### Modus untuk data tunggal
#
# Modus dari data tunggal adalah data yang paling sering muncul
#
# **Contoh :**
#
# Tentukan modus dari data berikut ! 4.6, 4.7, 4.7, 4.9, 5.0,5.1, 5.4, 5.6, 5.8, 6.3, 6.3, 6.5, 7.1, 7.3, 7.6
#
# Penyelesaian : Data yang paling sering muncul adalah 6.3, maka Mo = 6.3
#
#
# ---
#
# ### Modus untuk data berkelompok
#
# > $ Mo = T_{b} + \frac{d1}{d1+d2}.c $
#
# Keterangan :
#
# *   $ Tb $ = Tepi bawah kelas modus
# *   $ d1 $ = Selisih antara frekuensi modus dengan frekuensi sebelumnya
# *   $ d2 $ = Selisih antara frekuensi modus dengan frekuensi sesudahnya
# *   $ c $ = Panjang kelas
#
# **Contoh :**
#
# |||||
# |--- |--- |--- |--- |
# |**Interval Jumlah**|**Frekuensi ( $f$ )**|**Frekuensi Kumulatif ( $x$ )**|
# | 4.5 – 5 | 4 | 4.75 |
# | 5 – 5.5	| 3 | 5.2 |
# | 5.5 – 6	| 2 | 5.7 |
# | 6 - 6.5 | 2 | 6.3 |
# | 6.5 - 7 | 1 | 6.5 |
# | 7 - 7.5 | 2 | 7.2 |
# | 7.5 - 8 | 1 | 7.5 |
# | Jumlah | $\sum{f} = $ 	15 | | - |
# ||||
#
# Penyelesaian :
#
# *   Kelas modul = kelas ke-1
# *   $ Tb $ = 4.5-0.5 = 4
# *   $ d1 $ = 7 – 0 = 7
# *   $ d2 $ = 7 – 3 = 4
# *   $ c $ = 0.5
#
# $ Mo = T_{b} + \frac{d1}{d1+d2}.c = 4 + (\frac{7}{7+4}).0.5 = 4.315 $

# %% [markdown]
# ## Kuartil
#
# Kuartil adalah nilai yang membagi suatu data terurut atau sekumpulan data yang telah diurutkan menjadi empat bagian.
#
# ---
#
# Kuartil dialmbangkan dengan $Q$ . Dalam satu urutan data terdapat 3 jenis kuartil yaitu, kuartil bawah $(Q_{1})$, kuartil tengah $(Q_{2})$, dan kuartil atas $(Q_{3})$. Cara menentukan kuartil adalah sebagai berikut:
#
# *   Kuartil bawah adalah data pada posisi 1/4 dari kumpulan data yang telah diurutkan.
# *   Kuartil tengah adalah data pada posisi 2/4 dari kumpulan data yang telah diurutkan. Kuartil tengah sama dengan median.
# *   Kuartil atas adalah data pada posisi 3/4 dari kumpulan data yang telah diurutkan.
#
#
# ### Kuartil untuk data tunggal
#
# > $Q_{i} =  \frac{i(n+1)}{4}$
#
# Keterangan :
#
# *   $ Q_{i} $ = Kuartil ke-$i$
# *   $ n $ =  Banyaknya data
#
# **Contoh :**
#
# Tentukan $Q_{1}$, $Q_{2}$, dan $Q_{3}$ dari  4.6, 4.7, 4.7, 4.9, 5.0,5.1, 5.4, 5.6, 5.8, 6.3, 6.3, 6.5, 7.1, 7.3, 7.6
#
# Penyelesaian :
#
# *   Data terurut 4.6, 4.7, 4.7, 4.9, 5.0,5.1, 5.4, 5.6, 5.8, 6.3, 6.3, 6.5, 7.1, 7.3, 7.6
# *   $ n $ = 17
#
# $ Q_{1} =  \frac{i(n+1)}{4} = \frac{1(15+1)}{4} = \frac{16}{4} = 4 $
#
# $ Q_{1} = X_{4}+0,5(X_{5}+X_{4}) = 4.9 +0,5(5.0-4.9) = 4.95 $
#
# $ Q_{2} =  \frac{i(n+1)}{4} = \frac{2(15+1)}{4} = \frac{16}{2} = 8 $
#
# $ Q_{3} =  \frac{i(n+1)}{4} = \frac{3(15+1)}{4} = \frac{48}{4} = 12 $
#
# $ Q_{3} = X_{12}+0,5(X_{13}+X_{12}) = 6.5 +0,5(7.1-6.5) = 6.8 $
#
# ---
#
# ### Kuartil untuk data berkelompok
#
# > $Q_{i} = Tb+p\left(\frac{\frac{i.n}{4}-F}{f}\right)$
#
# Keterangan :
#
# *   $ Q_{i} $ = Kuartil ke-$i$
# *   $ n $ =  Banyaknya data
# *   $ Tb $ = Tepi bawah kelas kuartil
# *   $ p $ = Panjang kelas
# *   $ F $= Frekuensi kumulatif sebelum kelas kuartil
# *   $ f $ = Frekuensi kelas kuartil
#
# **Contoh :**
#
# Tentukan $Q_{i}$ dari data berikut:
#
# |||||
# |--- |--- |--- |--- |
# |**Interval Jumlah**|**Frekuensi ( $f$ )**|
# | ***4.5 – 5*** | ***4*** |
# | 5 – 5.5	| 3 |
# | 5.5 – 6	| 2 |
# | 6 - 6.5 | 2 |
# | 6.5 - 7 | 1 |
# | 7 - 7.5 | 2 |
# | 7.5 - 8 | 1 |
# | Jumlah | $\sum{f} = $ 	15 | | - |
# ||||
#
# Penyelesaian :
#
# |||
# |--- |--- |
# |**Data**|**f**|
# |11-20|2|
# |***21-30***|***7***|
# |31-44|4|
# |45-50|6|
# |51-60|5|
# |61-70|6|
#
# $Q_{i} = Tb+p\left(\frac{\frac{i.n}{4}-F}{f}\right) = (4.5-0.5)+0.5\left(\frac{4,5-0}{4}\right) = 5.0625$

# %% [markdown]
# ## Desil
# Desil merupakan nilai yang membagi data terurut atau data yang telah diurutkan menjadi sepuluh bagian.
#
# ---
#
# Desil sering dilambangkan dengan $D$. Dalam satu urutan data terdapat 9 desil masing masing disebut $D_{1}$, $D_{2}$, $D_{3}$, ..., ...., $D_{9}$
#
# ### Desil untuk data tunggal
#
# > $D_{i} =  \frac{i(n+1)}{10}$
#
# Keterangan :
#
# *   $ D_{i} $ = Desil ke-$i$
# *   $ n $ =  Banyaknya data
#
# **Contoh :**
#
# Tentukan desil ke-5 dari data : 4.6, 4.7, 4.7, 4.9, 5.0,5.1, 5.4, 5.6, 5.8, 6.3, 6.3, 6.5, 7.1, 7.3, 7.6
#
# Penyelesaian :
#
# *   Data terurut = 3,3,4,5,5,5,6,6,7,7,7,8,8,9,9,9
# *   $n$ = 15
#
# $D_{8} =  \frac{i(n+1)}{10} = \frac{5(15+1)}{10} = 8$
#
#
# ---
#
# ### Desil untuk data berkelompok
#
# > $D_{i} = Tb+p\left(\frac{\frac{i.n}{10}-F}{f}\right)$
#
# Keterangan :
#
# *   $ D_{i} $ = Desil ke-$i$
# *   $ n $ =  Banyaknya data
# *   $ Tb $ = Tepi bawah kelas desil
# *   $ p $ = Panjang kelas
# *   $ F $= Frekuensi kumulatif sebelum kelas desil
# *   $ f $ = Frekuensi kelas desil
#
# Tentukan $D_{6}$ dari data berikut:
#
# |||||
# |--- |--- |--- |--- |
# |**Interval Jumlah**|**Frekuensi ( $f$ )**|
# | ***4.5 – 5*** | ***4*** |
# | 5 – 5.5	| 3 |
# | 5.5 – 6	| 2 |
# | 6 - 6.5 | 2 |
# | 6.5 - 7 | 1 |
# | 7 - 7.5 | 2 |
# | 7.5 - 8 | 1 |
# | Jumlah | $\sum{f} = $ 	15 | | - |
# ||||
# Penyelesaian :
#
# |||
# |--- |--- |
# |**Data**|**f**|**f$_{k}$**|
# |11-13|5|5|
# |14-16|6|11|
# |17-19|3|***14***|
# |***20-22***|***5***|19|
# |23-25|7|26|
# |27-28|4|30|
#
# $D_{6} = Tb+p\left(\frac{\frac{i.n}{10}-F}{f}\right) = 19,5+3\left(\frac{18-14}{5}\right) = 21,9$
#
# Jadi, nilai $D_{6}$ adalah 21,9
